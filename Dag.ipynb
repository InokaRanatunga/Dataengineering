# %%
# Air flow DAG
# weather_etl_dag.py
from airflow import DAG
from airflow.operators.python_operator import PythonOperator
from airflow.operators.dummy_operator import DummyOperator
from datetime import datetime, timedelta
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Air flow DAG
#       2 # weather_etl_dag.py
# ----> 3 from airflow import DAG
#       4 from airflow.operators.python_operator import PythonOperator
#       5 from airflow.operators.dummy_operator import DummyOperator
#
# ModuleNotFoundError: No module named 'airflow'

# %%
with DAG(
    'weather_etl_pipeline',
    default_args=default_args,
    description='ETL pipeline for historical weather data',
    schedule_interval='@daily',
    catchup=False
) as dag:
    
    start = DummyOperator(task_id='start')
    
    extract = PythonOperator(
        task_id='extract_data',
        python_callable=extract_task,
        provide_context=True
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with DAG(
#       2     'weather_etl_pipeline',
#       3     default_args=default_args,
#       4     description='ETL pipeline for historical weather data',
#       5     schedule_interval='@daily',
#       6     catchup=False
#       7 ) as dag:
#       9     start = DummyOperator(task_id='start')
#      11     extract = PythonOperator(
#      12         task_id='extract_data',
#      13         python_callable=extract_task,
#      14         provide_context=True
#      15     )
#
# NameError: name 'DAG' is not defined
